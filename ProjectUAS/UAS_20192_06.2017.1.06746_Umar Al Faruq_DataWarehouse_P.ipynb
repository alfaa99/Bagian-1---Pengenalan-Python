# %%
import pandas as pd

# read all data
dataset = pd.read_csv('dataset1.csv')
dataset
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
dataset.dtypes
# Out:
# gender                      object
# NationalITy                 object
# PlaceofBirth                object
# StageID                     object
# GradeID                     object
# SectionID                   object
# Topic                       object
# Semester                    object
# Relation                    object
# raisedhands                  int64
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentAnsweringSurvey       object
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
#Laporan jurusan yang diambil di universitas

apply_Topic = dataset['Topic'].value_counts().reset_index()
apply_Topic.columns = ['Topic', 'count']
apply_Topic
# Out:
#         Topic  count
# 0          IT     95
# 1      French     65
# 2      Arabic     59
# 3     Science     51
# 4     English     45
# 5     Biology     30
# 6     Spanish     25
# 7   Chemistry     24
# 8     Geology     24
# 9       Quran     22
# 10       Math     21
# 11    History     19

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.bar(apply_Topic['Topic'], apply_Topic['count'])
plt.xlabel('Topic')
plt.ylabel('Count')
plt.show()

# %%
#Laporan Rata-Rata Performa Siswa 

raisedhands_mean = dataset['raisedhands'].mean()
VisITedResources_mean = dataset['VisITedResources'].mean()
AnnouncementsView_mean = dataset['AnnouncementsView'].mean()
Discussion_mean = dataset['Discussion'].mean()
contoh_data = [['raisedhands', raisedhands_mean], ['VisITedResources', VisITedResources_mean], ['AnnouncementsView', AnnouncementsView_mean],['Discussion',Discussion_mean]]
contoh_data_frame =  pd.DataFrame(contoh_data, columns=['Performa', 'Rata-Rata'])
contoh_data_frame
# Out:
#             Performa  Rata-Rata
# 0        raisedhands  46.775000
# 1   VisITedResources  54.797917
# 2  AnnouncementsView  37.918750
# 3         Discussion  43.283333

# %%
plt.figure(figsize=(12,8))
plt.bar(contoh_data_frame['Performa'], contoh_data_frame['Rata-Rata'])
plt.title('Rata-Rata Performa Siswa')
plt.xlabel('Performa')
plt.ylabel('Rata-Rata')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_1bulan = elektro.loc['2018-01':'2018-01-30']
